# %% [markdown]
# #### representation visualization of EMO model

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn import datasets
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings('ignore')

def plot_embedding(data, label, title):
    x_min, x_max = np.min(data, 0), np.max(data, 0)
    data = (data - x_min) / (x_max - x_min)

    fig = plt.figure()
    ax = plt.subplot(111)
    for i in range(data.shape[0]):
        plt.text(data[i, 0], data[i, 1], str(label[i]),
                 color=plt.cm.Set1(label[i] / 10.),
                 fontdict={'weight': 'bold', 'size': 9})
    plt.xticks([])
    plt.yticks([])
    plt.title(title)
    return fig

# %%
# load datasets
input = np.load("../model/middle_output/small/input.npy",allow_pickle=True) # (4302, 1000, 5)
output = np.load("../model/middle_output/small/output.npy",allow_pickle=True) # (4302, 32)
label = np.load("../model/middle_output/small/label.npy",allow_pickle=True) # (4302, 2)
label = np.argmax(label, axis=-1) # (4302,)
print(label.shape)
# Out:
# (4302,)

# %%
stack = np.sum(input, axis=1)

fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(stack.shape)
result = tsne.fit_transform(stack)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)

color = ["#FFD700","#5F9EA0"]
#color = ["#B0E0E6","#EE6363"]

ax = plt.subplots(figsize=(5,5))
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=10,color=color[label[i]])
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=10,color=color[label[i]])
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('t-SNE embedding of the input layer (Small Model)')
plt.legend((s1,s2),('non-sensitive','sensitive') ,loc = 'best')
plt.savefig('images/tsne/input-small.png',dpi=300)
plt.show()
# Out:
# (4302, 5)
# (4302, 2)

# %%
fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(output.shape)
result = tsne.fit_transform(output)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)

color = ["#FFD700","#5F9EA0"]
#color = ["#B0E0E6","#EE6363"]

ax = plt.subplots(figsize=(5,5))
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=10,color=color[label[i]])
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=10,color=color[label[i]])
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('t-SNE embedding of the final FC layer (Small Model)')
plt.legend((s1,s2),('Down-regulation','Up-regulation') ,loc = 'best')
plt.savefig('images/tsne/output-small.png',dpi=300)
plt.show()
# Out:
# (4302, 32)
# (4302, 2)

# %%
# load datasets
input = np.load("../model/middle_output/middle/input.npy",allow_pickle=True) # (5787, 10000, 5)
output = np.load("../model/middle_output/middle/output.npy",allow_pickle=True) # (5787, 32)
label = np.load("../model/middle_output/middle/label.npy",allow_pickle=True) # (5787, 2)
label = np.argmax(label, axis=-1) # (5787,)
print(label.shape)
# Out:
# (5787,)

# %%
stack = np.sum(input, axis=1)

fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(stack.shape)
result = tsne.fit_transform(stack)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)

color = ["#FFD700","#5F9EA0"]
#color = ["#B0E0E6","#EE6363"]

ax = plt.subplots(figsize=(5,5))
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=10,color=color[label[i]])
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=10,color=color[label[i]])
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('t-SNE embedding of the input layer (Middle Model)')
plt.legend((s1,s2),('non-sensitive','sensitive') ,loc = 'best')
plt.savefig('images/tsne/input-middle.png',dpi=300)
plt.show()
# Out:
# (5787, 5)
# (5787, 2)

# %%
fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(output.shape)
result = tsne.fit_transform(output)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)

color = ["#FFD700","#5F9EA0"]
#color = ["#B0E0E6","#EE6363"]

ax = plt.subplots(figsize=(5,5))
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=10,color=color[label[i]])
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=10,color=color[label[i]])
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('t-SNE embedding of the final FC layer (Middle Model)')
plt.legend((s1,s2),('Down-regulation','Up-regulation') ,loc = 'best')
plt.savefig('images/tsne/output-middle.png',dpi=300)
plt.show()
# Out:
# (5787, 32)
# (5787, 2)

# %%
# load datasets
input = np.load("../model/middle_output/large/input.npy",allow_pickle=True) # have been sumed by axis-1 before
output = np.load("../model/middle_output/large/output.npy",allow_pickle=True) 
label = np.load("../model/middle_output/large/label.npy",allow_pickle=True) 
label = np.argmax(label, axis=-1)

# %%
stack = input

fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
result = tsne.fit_transform(stack)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)

color = ["#FFD700","#5F9EA0"]
#color = ["#B0E0E6","#EE6363"]

ax = plt.subplots(figsize=(5,5))
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=10,color=color[label[i]])
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=10,color=color[label[i]])
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('t-SNE embedding of the input layer (Large Model)')
plt.legend((s1,s2),('non-sensitive','sensitive') ,loc = 'best')
plt.savefig('images/tsne/input-large.png',dpi=300)
plt.show()

# %%
fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
result = tsne.fit_transform(output)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)

color = ["#FFD700","#5F9EA0"]
#color = ["#B0E0E6","#EE6363"]

ax = plt.subplots(figsize=(5,5))
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=10,color=color[label[i]])
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=10,color=color[label[i]])
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('t-SNE embedding of the final FC layer (Large Model)')
plt.legend((s1,s2),('Down-regulation','Up-regulation') ,loc = 'best')
plt.savefig('images/tsne/output-large.png',dpi=300)
plt.show()
