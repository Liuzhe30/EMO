# %% [markdown]
# #### prediction performance of Enformer

# %%
import numpy as np
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import precision_score, accuracy_score,recall_score, f1_score
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import roc_curve, auc
from prettytable import PrettyTable

# %%
result_path = '../../datasets/tissue_specific/enformer_prediction_results/'

compare_tissue_list = ['Adipose_Subcutaneous','Artery_Tibial','Breast_Mammary_Tissue','Colon_Transverse','Nerve_Tibial','Thyroid']
model_size_list = ['small','middle','large']

# %%
for tissue in compare_tissue_list:
    for model_size in model_size_list:
        label = np.load(result_path + model_size + '_' + tissue + '_label.npy')
        y_score = np.load(result_path + model_size + '_' + tissue + '_score.npy')
        y_score_pro = np.load(result_path + model_size + '_' + tissue + '_score_pro.npy')
        y_one_hot = to_categorical(label)
        y_score_one_hot = to_categorical(y_score)

        acc = np.round(accuracy_score(label, y_score),3)
        precision = np.round(precision_score(label, y_score),3)
        recall = np.round(recall_score(label, y_score),3)
        f1 = np.round(f1_score(label, y_score),3)
        fpr, tpr, thresholds = roc_curve(y_one_hot.ravel(),y_score_pro.ravel()) 
        auc_ = np.round(auc(fpr, tpr),3)

        print('tissue: ', tissue)
        print('model size: ', model_size)
        table = PrettyTable(['ACC','Precision','Recall','F1-score','AUC'])
        table.add_row([acc,precision,recall,f1,auc_])
        print(table)
# Out:
# tissue:  Adipose_Subcutaneous
# model size:  small
# +-------+-----------+--------+----------+-------+
# |  ACC  | Precision | Recall | F1-score |  AUC  |
# +-------+-----------+--------+----------+-------+
# | 0.615 |   0.652   | 0.682  |  0.667   | 0.665 |
# +-------+-----------+--------+----------+-------+
# tissue:  Adipose_Subcutaneous
# model size:  middle
# +------+-----------+--------+----------+------+
# | ACC  | Precision | Recall | F1-score | AUC  |
# +------+-----------+--------+----------+------+
# | 0.59 |    0.68   |  0.5   |  0.576   | 0.66 |
# +------+-----------+--------+----------+------+
# tissue:  Adipose_Subcutaneous
# model size:  large
# +-------+-----------+--------+----------+------+
# |  ACC  | Precision | Recall | F1-score | AUC  |
# +-------+-----------+--------+----------+------+
# | 0.545 |   0.509   | 0.574  |   0.54   | 0.64 |
# +-------+-----------+--------+----------+------+
# tissue:  Artery_Tibial
# model size:  small
# +-------+-----------+--------+----------+------+
# |  ACC  | Precision | Recall | F1-score | AUC  |
# +-------+-----------+--------+----------+------+
# | 0.667 |    0.68   | 0.708  |  0.694   | 0.71 |
# +-------+-----------+--------+----------+------+
# tissue:  Artery_Tibial
# model size:  middle
# +-------+-----------+--------+----------+------+
# |  ACC  | Precision | Recall | F1-score | AUC  |
# +-------+-----------+--------+----------+------+
# | 0.544 |    0.56   | 0.483  |  0.519   | 0.59 |
# +-------+-----------+--------+----------+------+
# tissue:  Artery_Tibial
# model size:  large
# +-------+-----------+--------+----------+-------+
# |  ACC  | Precision | Recall | F1-score |  AUC  |
# +-------+-----------+--------+----------+-------+
# | 0.546 |   0.585   | 0.585  |  0.585   | 0.588 |
# +-------+-----------+--------+----------+-------+
# tissue:  Breast_Mammary_Tissue
# model size:  small
# +-------+-----------+--------+----------+-------+
# |  ACC  | Precision | Recall | F1-score |  AUC  |
# +-------+-----------+--------+----------+-------+
# | 0.522 |   0.778   | 0.438  |   0.56   | 0.516 |
# +-------+-----------+--------+----------+-------+
# tissue:  Breast_Mammary_Tissue
# model size:  middle
# +-------+-----------+--------+----------+-------+
# |  ACC  | Precision | Recall | F1-score |  AUC  |
# +-------+-----------+--------+----------+-------+
# | 0.633 |    0.6    | 0.643  |  0.621   | 0.588 |
# +-------+-----------+--------+----------+-------+
# tissue:  Breast_Mammary_Tissue
# model size:  large
# +-----+-----------+--------+----------+-------+
# | ACC | Precision | Recall | F1-score |  AUC  |
# +-----+-----------+--------+----------+-------+
# | 0.5 |   0.424   | 0.636  |  0.509   | 0.563 |
# +-----+-----------+--------+----------+-------+
# tissue:  Colon_Transverse
# model size:  small
# +-------+-----------+--------+----------+-------+
# |  ACC  | Precision | Recall | F1-score |  AUC  |
# +-------+-----------+--------+----------+-------+
# | 0.594 |    0.5    | 0.692  |  0.581   | 0.549 |
# +-------+-----------+--------+----------+-------+
# tissue:  Colon_Transverse
# model size:  middle
# +-------+-----------+--------+----------+-------+
# |  ACC  | Precision | Recall | F1-score |  AUC  |
# +-------+-----------+--------+----------+-------+
# | 0.395 |   0.444   | 0.381  |   0.41   | 0.463 |
# +-------+-----------+--------+----------+-------+
# tissue:  Colon_Transverse
# model size:  large
# +-------+-----------+--------+----------+-------+
# |  ACC  | Precision | Recall | F1-score |  AUC  |
# +-------+-----------+--------+----------+-------+
# | 0.524 |   0.647   |  0.44  |  0.524   | 0.581 |
# +-------+-----------+--------+----------+-------+
# tissue:  Nerve_Tibial
# model size:  small
# +-------+-----------+--------+----------+-------+
# |  ACC  | Precision | Recall | F1-score |  AUC  |
# +-------+-----------+--------+----------+-------+
# | 0.649 |   0.667   | 0.762  |  0.711   | 0.657 |
# +-------+-----------+--------+----------+-------+
# tissue:  Nerve_Tibial
# model size:  middle
# +-------+-----------+--------+----------+-------+
# |  ACC  | Precision | Recall | F1-score |  AUC  |
# +-------+-----------+--------+----------+-------+
# | 0.458 |   0.373   | 0.731  |  0.494   | 0.478 |
# +-------+-----------+--------+----------+-------+
# tissue:  Nerve_Tibial
# model size:  large
# +-------+-----------+--------+----------+-------+
# |  ACC  | Precision | Recall | F1-score |  AUC  |
# +-------+-----------+--------+----------+-------+
# | 0.541 |   0.508   | 0.588  |  0.545   | 0.573 |
# +-------+-----------+--------+----------+-------+
# tissue:  Thyroid
# model size:  small
# +-------+-----------+--------+----------+-------+
# |  ACC  | Precision | Recall | F1-score |  AUC  |
# +-------+-----------+--------+----------+-------+
# | 0.696 |   0.773   | 0.654  |  0.708   | 0.741 |
# +-------+-----------+--------+----------+-------+
# tissue:  Thyroid
# model size:  middle
# +-------+-----------+--------+----------+-------+
# |  ACC  | Precision | Recall | F1-score |  AUC  |
# +-------+-----------+--------+----------+-------+
# | 0.692 |   0.625   | 0.682  |  0.652   | 0.719 |
# +-------+-----------+--------+----------+-------+
# tissue:  Thyroid
# model size:  large
# +-------+-----------+--------+----------+-------+
# |  ACC  | Precision | Recall | F1-score |  AUC  |
# +-------+-----------+--------+----------+-------+
# | 0.487 |   0.465   | 0.611  |  0.528   | 0.498 |
# +-------+-----------+--------+----------+-------+
