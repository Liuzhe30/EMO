# %%
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import confusion_matrix, precision_score, accuracy_score,recall_score, f1_score,roc_auc_score
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics import roc_curve, auc

# %%
my_pal = {"Fine-tune": "#FFB6C1", "Emo prediction": "#4169E1", "End-to-end": "#E6E6FA"}

# %%
# small model (Fine-tune)
tissue_list = ['Adipose_Subcutaneous','Artery_Tibial','Breast_Mammary_Tissue','Colon_Transverse','Nerve_Tibial','Testis','Thyroid']
model_size = 'small'
for tissue in tissue_list:

    print('\n')
    print(tissue)
    y_true = np.load('../model/pred_results_finetune/' + model_size + '_' + tissue + '_' + 'label.npy')
    y_pred = np.load('../model/pred_results_finetune/' + model_size + '_' + tissue + '_' + 'predict.npy')

    y_score = y_pred.argmax(axis=1)       
    test_label = y_true.argmax(axis=1)                         
    y_score_pro = y_pred # (212, 2)
    y_one_hot = y_true
    y_score_one_hot = to_categorical(y_score)
    print('accuracy:{}'.format(accuracy_score(test_label, y_score)))
    print('precision:{}'.format(precision_score(test_label, y_score)))
    print('recall:{}'.format(recall_score(test_label, y_score)))
    print('f1-score:{}'.format(f1_score(test_label, y_score)))

    fpr_xgb, tpr_xgb, thresholds = roc_curve(y_one_hot.ravel(),y_score_pro.ravel())   
    auc_xgb = auc(fpr_xgb, tpr_xgb)
    print("AUC : ", auc_xgb)
# Out:
# Adipose_Subcutaneous
# accuracy:0.8205128205128205
# precision:0.8947368421052632
# recall:0.7727272727272727
# f1-score:0.8292682926829269
# AUC :  0.9089414858645627
#
#
# Artery_Tibial
# accuracy:0.8
# precision:0.8260869565217391
# recall:0.7916666666666666
# f1-score:0.8085106382978724
# AUC :  0.8567901234567901
#
#
# Breast_Mammary_Tissue
# accuracy:0.9583333333333334
# precision:0.9411764705882353
# recall:1.0
# f1-score:0.9696969696969697
# AUC :  0.9670138888888888
#
#
# Colon_Transverse
# accuracy:0.9696969696969697
# precision:0.9333333333333333
# recall:1.0
# f1-score:0.9655172413793104
# AUC :  0.9935720844811754
#
#
# Nerve_Tibial
# accuracy:0.918918918918919
# precision:0.9090909090909091
# recall:0.9523809523809523
# f1-score:0.9302325581395349
# AUC :  0.8780131482834186
#
#
# Testis
# accuracy:0.7391304347826086
# precision:0.7692307692307693
# recall:0.7692307692307693
# f1-score:0.7692307692307693
# AUC :  0.7901701323251418
#
#
# Thyroid
# accuracy:0.9347826086956522
# precision:0.9259259259259259
# recall:0.9615384615384616
# f1-score:0.9433962264150944
# AUC :  0.9536862003780718

# %%
# small model (end-to-end)
tissue_list = ['Adipose_Subcutaneous','Artery_Tibial','Breast_Mammary_Tissue','Colon_Transverse','Nerve_Tibial','Testis','Thyroid']
model_size = 'small'
for tissue in tissue_list:

    print('\n')
    print(tissue)
    y_true = np.load('../model/pred_results_e2e/' + model_size + '_' + tissue + '_' + 'label.npy')
    y_pred = np.load('../model/pred_results_e2e/' + model_size + '_' + tissue + '_' + 'predict.npy')

    y_score = y_pred.argmax(axis=1)       
    test_label = y_true.argmax(axis=1)                         
    y_score_pro = y_pred # (212, 2)
    y_one_hot = y_true
    y_score_one_hot = to_categorical(y_score)

    print('accuracy:{}'.format(accuracy_score(test_label, y_score)))
    print('precision:{}'.format(precision_score(test_label, y_score)))
    print('recall:{}'.format(recall_score(test_label, y_score)))
    print('f1-score:{}'.format(f1_score(test_label, y_score)))

    fpr_xgb, tpr_xgb, thresholds = roc_curve(y_one_hot.ravel(),y_score_pro.ravel())   
    auc_xgb = auc(fpr_xgb, tpr_xgb)
    print("AUC : ", auc_xgb)
# Out:
# Adipose_Subcutaneous
# accuracy:0.5897435897435898
# precision:0.5789473684210527
# recall:1.0
# f1-score:0.7333333333333334
# AUC :  0.4924391847468771
#
#
# Artery_Tibial
# accuracy:0.5333333333333333
# precision:0.5333333333333333
# recall:1.0
# f1-score:0.6956521739130436
# AUC :  0.5481481481481482
#
#
# Breast_Mammary_Tissue
# accuracy:0.625
# precision:0.6666666666666666
# recall:0.875
# f1-score:0.7567567567567567
# AUC :  0.6684027777777778
#
#
# Colon_Transverse
# accuracy:0.5757575757575758
# precision:0.0
# recall:0.0
# f1-score:0.0
# AUC :  0.5583103764921946
#
#
# Nerve_Tibial
# accuracy:0.6216216216216216
# precision:0.6206896551724138
# recall:0.8571428571428571
# f1-score:0.7200000000000001
# AUC :  0.5427319211102994
#
#
# Testis
# accuracy:0.6086956521739131
# precision:0.6428571428571429
# recall:0.6923076923076923
# f1-score:0.6666666666666666
# AUC :  0.555765595463138
#
#
# Thyroid
# accuracy:0.6304347826086957
# precision:0.6551724137931034
# recall:0.7307692307692307
# f1-score:0.6909090909090909
# AUC :  0.584593572778828
# c:\Users\Administrator\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# small model (EMO prediction)
tissue_list = ['Adipose_Subcutaneous','Artery_Tibial','Breast_Mammary_Tissue','Colon_Transverse','Nerve_Tibial','Testis','Thyroid']
model_size = 'small'
for tissue in tissue_list:

    print('\n')
    print(tissue)
    y_true = np.load('../model/pred_results_tissue/' + model_size + '_' + tissue + '_' + 'label.npy')
    y_pred = np.load('../model/pred_results_tissue/' + model_size + '_' + tissue + '_' + 'predict.npy')

    y_score = y_pred.argmax(axis=1)       
    test_label = y_true.argmax(axis=1)                         
    y_score_pro = y_pred # (212, 2)
    y_one_hot = y_true
    y_score_one_hot = to_categorical(y_score)

    print('accuracy:{}'.format(accuracy_score(test_label, y_score)))
    print('precision:{}'.format(precision_score(test_label, y_score)))
    print('recall:{}'.format(recall_score(test_label, y_score)))
    print('f1-score:{}'.format(f1_score(test_label, y_score)))

    fpr_xgb, tpr_xgb, thresholds = roc_curve(y_one_hot.ravel(),y_score_pro.ravel())   
    auc_xgb = auc(fpr_xgb, tpr_xgb)
    print("AUC : ", auc_xgb)
# Out:
# Adipose_Subcutaneous
# accuracy:0.8205128205128205
# precision:0.8571428571428571
# recall:0.8181818181818182
# f1-score:0.8372093023255814
# AUC :  0.9020381328073636
#
#
# Artery_Tibial
# accuracy:0.8
# precision:0.8260869565217391
# recall:0.7916666666666666
# f1-score:0.8085106382978724
# AUC :  0.8491358024691359
#
#
# Breast_Mammary_Tissue
# accuracy:0.9583333333333334
# precision:0.9411764705882353
# recall:1.0
# f1-score:0.9696969696969697
# AUC :  0.9661458333333333
#
#
# Colon_Transverse
# accuracy:0.9696969696969697
# precision:0.9333333333333333
# recall:1.0
# f1-score:0.9655172413793104
# AUC :  0.9807162534435263
#
#
# Nerve_Tibial
# accuracy:0.8918918918918919
# precision:0.8695652173913043
# recall:0.9523809523809523
# f1-score:0.909090909090909
# AUC :  0.8882395909422937
#
#
# Testis
# accuracy:0.717391304347826
# precision:0.7096774193548387
# recall:0.8461538461538461
# f1-score:0.7719298245614036
# AUC :  0.7875708884688091
#
#
# Thyroid
# accuracy:0.9347826086956522
# precision:0.9259259259259259
# recall:0.9615384615384616
# f1-score:0.9433962264150944
# AUC :  0.9560491493383744

# %%
import seaborn as sns

fine = [0.909,0.857,0.967,0.994,0.878,0.795,0.954]
end = [0.492,0.548,0.668,0.558,0.543,0.556,0.585]
pred = [0.902,0.849,0.966,0.981,0.888,0.788,0.956]

sns.set_style('ticks')

f, ax = plt.subplots(figsize=(4, 6))
df = pd.Series(fine, name="Fine-tune").to_frame().join(pd.Series(pred, name="Emo prediction")).join(pd.Series(end, name="End-to-end"))
sns.violinplot(data=df, palette=my_pal, bw=.3, cut=1, linewidth=1.5) 
plt.title('Tissue-specific prediction (Small Model)')
plt.ylabel('AUC')
plt.grid(axis='y')
ax.set_ylim(0.38,1.03)
plt.savefig('images/finetune/small-model.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
# middle model (finetune)
tissue_list = ['Adipose_Subcutaneous','Artery_Tibial','Brain_Cerebellum','Breast_Mammary_Tissue', 'Colon_Sigmoid','Testis',
    'Colon_Transverse','Nerve_Tibial', 'Pancreas', 'Spleen','Thyroid']
model_size = 'middle'
for tissue in tissue_list:

    print('\n')
    print(tissue)
    y_true = np.load('../model/pred_results_finetune/' + model_size + '_' + tissue + '_' + 'label.npy')
    y_pred = np.load('../model/pred_results_finetune/' + model_size + '_' + tissue + '_' + 'predict.npy')

    y_score = y_pred.argmax(axis=1)       
    test_label = y_true.argmax(axis=1)                         
    y_score_pro = y_pred # (212, 2)
    y_one_hot = y_true
    y_score_one_hot = to_categorical(y_score)

    print('accuracy:{}'.format(accuracy_score(test_label, y_score)))
    print('precision:{}'.format(precision_score(test_label, y_score)))
    print('recall:{}'.format(recall_score(test_label, y_score)))
    print('f1-score:{}'.format(f1_score(test_label, y_score)))

    fpr_xgb, tpr_xgb, thresholds = roc_curve(y_one_hot.ravel(),y_score_pro.ravel())   
    auc_xgb = auc(fpr_xgb, tpr_xgb)
    print("AUC : ", auc_xgb)
# Out:
# Adipose_Subcutaneous
# accuracy:0.8360655737704918
# precision:0.8529411764705882
# recall:0.8529411764705882
# f1-score:0.8529411764705882
# AUC :  0.9135984950282182
#
#
# Artery_Tibial
# accuracy:0.8596491228070176
# precision:0.8387096774193549
# recall:0.896551724137931
# f1-score:0.8666666666666666
# AUC :  0.8801169590643274
#
#
# Brain_Cerebellum
# accuracy:0.7428571428571429
# precision:0.7222222222222222
# recall:0.7647058823529411
# f1-score:0.7428571428571428
# AUC :  0.8391836734693877
#
#
# Breast_Mammary_Tissue
# accuracy:0.9666666666666667
# precision:0.9333333333333333
# recall:1.0
# f1-score:0.9655172413793104
# AUC :  0.9544444444444444
#
#
# Colon_Sigmoid
# accuracy:0.96
# precision:1.0
# recall:0.9375
# f1-score:0.967741935483871
# AUC :  0.9792000000000001
#
#
# Testis
# accuracy:0.6111111111111112
# precision:0.6774193548387096
# recall:0.65625
# f1-score:0.6666666666666667
# AUC :  0.6351165980795611
#
#
# Colon_Transverse
# accuracy:0.9210526315789473
# precision:1.0
# recall:0.8571428571428571
# f1-score:0.923076923076923
# AUC :  0.9743767313019391
#
#
# Nerve_Tibial
# accuracy:0.875
# precision:0.8148148148148148
# recall:0.8461538461538461
# f1-score:0.830188679245283
# AUC :  0.9118441358024691
#
#
# Pancreas
# accuracy:0.8285714285714286
# precision:0.8
# recall:0.8
# f1-score:0.8000000000000002
# AUC :  0.9069387755102041
#
#
# Spleen
# accuracy:0.8214285714285714
# precision:0.8823529411764706
# recall:0.8333333333333334
# f1-score:0.8571428571428571
# AUC :  0.8233418367346939
#
#
# Thyroid
# accuracy:0.8076923076923077
# precision:0.7727272727272727
# recall:0.7727272727272727
# f1-score:0.7727272727272727
# AUC :  0.9208579881656804

# %%
# middle model (end-to-end)
tissue_list = ['Adipose_Subcutaneous','Artery_Tibial','Brain_Cerebellum','Breast_Mammary_Tissue', 'Colon_Sigmoid','Testis',
    'Colon_Transverse','Nerve_Tibial', 'Pancreas', 'Spleen','Thyroid']
model_size = 'middle'
for tissue in tissue_list:

    print('\n')
    print(tissue)
    y_true = np.load('../model/pred_results_e2e/' + model_size + '_' + tissue + '_' + 'label.npy')
    y_pred = np.load('../model/pred_results_e2e/' + model_size + '_' + tissue + '_' + 'predict.npy')

    y_score = y_pred.argmax(axis=1)       
    test_label = y_true.argmax(axis=1)                         
    y_score_pro = y_pred # (212, 2)
    y_one_hot = y_true
    y_score_one_hot = to_categorical(y_score)

    print('accuracy:{}'.format(accuracy_score(test_label, y_score)))
    print('precision:{}'.format(precision_score(test_label, y_score)))
    print('recall:{}'.format(recall_score(test_label, y_score)))
    print('f1-score:{}'.format(f1_score(test_label, y_score)))

    fpr_xgb, tpr_xgb, thresholds = roc_curve(y_one_hot.ravel(),y_score_pro.ravel())   
    auc_xgb = auc(fpr_xgb, tpr_xgb)
    print("AUC : ", auc_xgb)
# Out:
# Adipose_Subcutaneous
# accuracy:0.5409836065573771
# precision:0.59375
# recall:0.5588235294117647
# f1-score:0.5757575757575757
# AUC :  0.5084654662725073
#
#
# Artery_Tibial
# accuracy:0.543859649122807
# precision:0.5428571428571428
# recall:0.6551724137931034
# f1-score:0.5937499999999999
# AUC :  0.4626038781163435
#
#
# Brain_Cerebellum
# accuracy:0.5142857142857142
# precision:0.0
# recall:0.0
# f1-score:0.0
# AUC :  0.5044897959183674
#
#
# Breast_Mammary_Tissue
# accuracy:0.5333333333333333
# precision:0.0
# recall:0.0
# f1-score:0.0
# AUC :  0.5405555555555556
#
#
# Colon_Sigmoid
# accuracy:0.72
# precision:0.8
# recall:0.75
# f1-score:0.7741935483870969
# AUC :  0.7584000000000001
#
#
# Testis
# accuracy:0.5
# precision:0.5925925925925926
# recall:0.5
# f1-score:0.5423728813559322
# AUC :  0.49022633744855965
#
#
# Colon_Transverse
# accuracy:0.5526315789473685
# precision:0.5909090909090909
# recall:0.6190476190476191
# f1-score:0.6046511627906977
# AUC :  0.5463988919667591
#
#
# Nerve_Tibial
# accuracy:0.5416666666666666
# precision:0.36
# recall:0.34615384615384615
# f1-score:0.35294117647058826
# AUC :  0.5202546296296297
#
#
# Pancreas
# accuracy:0.5714285714285714
# precision:0.5
# recall:0.4
# f1-score:0.4444444444444445
# AUC :  0.5959183673469387
#
#
# Spleen
# accuracy:0.6071428571428571
# precision:0.6666666666666666
# recall:0.7777777777777778
# f1-score:0.717948717948718
# AUC :  0.5918367346938775
#
#
# Thyroid
# accuracy:0.5769230769230769
# precision:0.5
# recall:0.8181818181818182
# f1-score:0.6206896551724137
# AUC :  0.5103550295857988
# c:\Users\Administrator\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Administrator\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# middle model (EMO prediction)
tissue_list = ['Adipose_Subcutaneous','Artery_Tibial','Brain_Cerebellum','Breast_Mammary_Tissue', 'Colon_Sigmoid','Testis',
    'Colon_Transverse','Nerve_Tibial', 'Pancreas', 'Spleen','Thyroid']
model_size = 'middle'
for tissue in tissue_list:

    print('\n')
    print(tissue)
    y_true = np.load('../model/pred_results_tissue/' + model_size + '_' + tissue + '_' + 'label.npy')
    y_pred = np.load('../model/pred_results_tissue/' + model_size + '_' + tissue + '_' + 'predict.npy')

    y_score = y_pred.argmax(axis=1)       
    test_label = y_true.argmax(axis=1)                         
    y_score_pro = y_pred # (212, 2)
    y_one_hot = y_true
    y_score_one_hot = to_categorical(y_score)

    print('accuracy:{}'.format(accuracy_score(test_label, y_score)))
    print('precision:{}'.format(precision_score(test_label, y_score)))
    print('recall:{}'.format(recall_score(test_label, y_score)))
    print('f1-score:{}'.format(f1_score(test_label, y_score)))

    fpr_xgb, tpr_xgb, thresholds = roc_curve(y_one_hot.ravel(),y_score_pro.ravel())   
    auc_xgb = auc(fpr_xgb, tpr_xgb)
    print("AUC : ", auc_xgb)
# Out:
# Adipose_Subcutaneous
# accuracy:0.8524590163934426
# precision:0.8571428571428571
# recall:0.8823529411764706
# f1-score:0.8695652173913043
# AUC :  0.9083579682880946
#
#
# Artery_Tibial
# accuracy:0.8421052631578947
# precision:0.8333333333333334
# recall:0.8620689655172413
# f1-score:0.847457627118644
# AUC :  0.8725761772853186
#
#
# Brain_Cerebellum
# accuracy:0.7714285714285715
# precision:0.7368421052631579
# recall:0.8235294117647058
# f1-score:0.7777777777777778
# AUC :  0.8253061224489795
#
#
# Breast_Mammary_Tissue
# accuracy:0.9666666666666667
# precision:0.9333333333333333
# recall:1.0
# f1-score:0.9655172413793104
# AUC :  0.9455555555555556
#
#
# Colon_Sigmoid
# accuracy:0.96
# precision:1.0
# recall:0.9375
# f1-score:0.967741935483871
# AUC :  0.9856
#
#
# Testis
# accuracy:0.5740740740740741
# precision:0.6285714285714286
# recall:0.6875
# f1-score:0.6567164179104478
# AUC :  0.6244855967078189
#
#
# Colon_Transverse
# accuracy:0.9210526315789473
# precision:1.0
# recall:0.8571428571428571
# f1-score:0.923076923076923
# AUC :  0.9702216066481995
#
#
# Nerve_Tibial
# accuracy:0.875
# precision:0.7741935483870968
# recall:0.9230769230769231
# f1-score:0.8421052631578947
# AUC :  0.8968942901234569
#
#
# Pancreas
# accuracy:0.8
# precision:0.7857142857142857
# recall:0.7333333333333333
# f1-score:0.7586206896551724
# AUC :  0.9061224489795918
#
#
# Spleen
# accuracy:0.7857142857142857
# precision:0.8333333333333334
# recall:0.8333333333333334
# f1-score:0.8333333333333334
# AUC :  0.8080357142857143
#
#
# Thyroid
# accuracy:0.8269230769230769
# precision:0.8095238095238095
# recall:0.7727272727272727
# f1-score:0.7906976744186046
# AUC :  0.9227071005917159

# %%
import seaborn as sns
fine = [0.914,0.880,0.839,0.954,0.989,0.974,0.912,0.907,0.828,0.645,0.921]
end = [0.508,0.462,0.504,0.541,0.758,0.546,0.520,0.596,0.592,0.490,0.510]
pred = [0.908,0.873,0.825,0.946,0.976,0.970,0.897,0.906,0.808,0.624,0.923]


f, ax = plt.subplots(figsize=(4, 6))
df = pd.Series(fine, name="Fine-tune").to_frame().join(pd.Series(pred, name="Emo prediction")).join(pd.Series(end, name="End-to-end"))
sns.violinplot(data=df, palette=my_pal, bw=.3, cut=1, linewidth=1.5) 
plt.title('Tissue-specific prediction (Middle Model)')
plt.ylabel('AUC')
plt.grid(axis='y')
ax.set_ylim(0.38,1.03)
plt.savefig('images/finetune/middle-model.png',dpi=300,bbox_inches='tight')
plt.show()

# %%
# large model (finetune)
tissue_list = ['Adipose_Subcutaneous','Artery_Tibial','Brain_Cerebellum','Brain_Cortex',
    'Breast_Mammary_Tissue', 'Colon_Sigmoid','Colon_Transverse','Nerve_Tibial', 'Pancreas', 'Spleen','Stomach','Testis','Thyroid']
model_size = 'large'
for tissue in tissue_list:

    print('\n')
    print(tissue)
    y_true = np.load('../model/pred_results_finetune/' + model_size + '_' + tissue + '_' + 'label.npy')
    y_pred = np.load('../model/pred_results_finetune/' + model_size + '_' + tissue + '_' + 'predict.npy')

    y_score = y_pred.argmax(axis=1)       
    test_label = y_true.argmax(axis=1)                         
    y_score_pro = y_pred # (212, 2)
    y_one_hot = y_true
    y_score_one_hot = to_categorical(y_score)

    print('accuracy:{}'.format(accuracy_score(test_label, y_score)))
    print('precision:{}'.format(precision_score(test_label, y_score)))
    print('recall:{}'.format(recall_score(test_label, y_score)))
    print('f1-score:{}'.format(f1_score(test_label, y_score)))

    fpr_xgb, tpr_xgb, thresholds = roc_curve(y_one_hot.ravel(),y_score_pro.ravel())   
    auc_xgb = auc(fpr_xgb, tpr_xgb)
    print("AUC : ", auc_xgb)
# Out:
# Adipose_Subcutaneous
# accuracy:0.7029702970297029
# precision:0.660377358490566
# recall:0.7446808510638298
# f1-score:0.7
# AUC :  0.8053132045877854
#
#
# Artery_Tibial
# accuracy:0.7010309278350515
# precision:0.6714285714285714
# recall:0.8867924528301887
# f1-score:0.7642276422764227
# AUC :  0.7871187161228612
#
#
# Brain_Cerebellum
# accuracy:0.6666666666666666
# precision:0.6842105263157895
# recall:0.8125
# f1-score:0.742857142857143
# AUC :  0.7414266117969822
#
#
# Brain_Cortex
# accuracy:0.6875
# precision:0.7647058823529411
# recall:0.6842105263157895
# f1-score:0.7222222222222222
# AUC :  0.68359375
#
#
# Breast_Mammary_Tissue
# accuracy:0.7592592592592593
# precision:0.6956521739130435
# recall:0.7272727272727273
# f1-score:0.711111111111111
# AUC :  0.7362825788751715
#
#
# Colon_Sigmoid
# accuracy:0.7727272727272727
# precision:0.782608695652174
# recall:0.782608695652174
# f1-score:0.782608695652174
# AUC :  0.8460743801652892
#
#
# Colon_Transverse
# accuracy:0.7727272727272727
# precision:0.7419354838709677
# recall:0.92
# f1-score:0.8214285714285714
# AUC :  0.8657024793388429
#
#
# Nerve_Tibial
# accuracy:0.7699115044247787
# precision:0.8333333333333334
# recall:0.6481481481481481
# f1-score:0.7291666666666669
# AUC :  0.7893335421724489
#
#
# Pancreas
# accuracy:0.5869565217391305
# precision:0.5
# recall:0.631578947368421
# f1-score:0.5581395348837209
# AUC :  0.6781663516068053
#
#
# Spleen
# accuracy:0.7708333333333334
# precision:0.7741935483870968
# recall:0.8571428571428571
# f1-score:0.8135593220338982
# AUC :  0.85546875
#
#
# Stomach
# accuracy:0.7058823529411765
# precision:0.6956521739130435
# recall:0.8421052631578947
# f1-score:0.761904761904762
# AUC :  0.7975778546712803
#
#
# Testis
# accuracy:0.6052631578947368
# precision:0.625
# recall:0.625
# f1-score:0.625
# AUC :  0.6741689750692521
#
#
# Thyroid
# accuracy:0.6752136752136753
# precision:0.7045454545454546
# recall:0.5535714285714286
# f1-score:0.62
# AUC :  0.7207977207977208

# %%
# large model (end-to-end)
tissue_list = ['Adipose_Subcutaneous','Artery_Tibial','Brain_Cerebellum','Brain_Cortex',
    'Breast_Mammary_Tissue', 'Colon_Sigmoid','Colon_Transverse','Nerve_Tibial', 'Pancreas', 'Spleen','Stomach','Testis','Thyroid']
model_size = 'large'
for tissue in tissue_list:

    print('\n')
    print(tissue)
    y_true = np.load('../model/pred_results_e2e/' + model_size + '_' + tissue + '_' + 'label.npy')
    y_pred = np.load('../model/pred_results_e2e/' + model_size + '_' + tissue + '_' + 'predict.npy')

    y_score = y_pred.argmax(axis=1)       
    test_label = y_true.argmax(axis=1)                         
    y_score_pro = y_pred # (212, 2)
    y_one_hot = y_true
    y_score_one_hot = to_categorical(y_score)

    print('accuracy:{}'.format(accuracy_score(test_label, y_score)))
    print('precision:{}'.format(precision_score(test_label, y_score)))
    print('recall:{}'.format(recall_score(test_label, y_score)))
    print('f1-score:{}'.format(f1_score(test_label, y_score)))
    
    fpr_xgb, tpr_xgb, thresholds = roc_curve(y_one_hot.ravel(),y_score_pro.ravel())   
    auc_xgb = auc(fpr_xgb, tpr_xgb)
    print("AUC : ", auc_xgb)
# Out:
# Adipose_Subcutaneous
# accuracy:0.5841584158415841
# precision:0.5423728813559322
# recall:0.6808510638297872
# f1-score:0.6037735849056605
# AUC :  0.5837662974218214
#
#
# Artery_Tibial
# accuracy:0.5567010309278351
# precision:0.6785714285714286
# recall:0.3584905660377358
# f1-score:0.46913580246913583
# AUC :  0.557976405569136
#
#
# Brain_Cerebellum
# accuracy:0.5740740740740741
# precision:0.6363636363636364
# recall:0.65625
# f1-score:0.6461538461538462
# AUC :  0.5936213991769547
#
#
# Brain_Cortex
# accuracy:0.40625
# precision:0.0
# recall:0.0
# f1-score:0.0
# AUC :  0.41455078125
#
#
# Breast_Mammary_Tissue
# accuracy:0.5740740740740741
# precision:0.48484848484848486
# recall:0.7272727272727273
# f1-score:0.5818181818181818
# AUC :  0.6375171467764059
#
#
# Colon_Sigmoid
# accuracy:0.5227272727272727
# precision:0.5227272727272727
# recall:1.0
# f1-score:0.6865671641791045
# AUC :  0.5901342975206612
#
#
# Colon_Transverse
# accuracy:0.6136363636363636
# precision:0.5952380952380952
# recall:1.0
# f1-score:0.7462686567164178
# AUC :  0.5945247933884299
#
#
# Nerve_Tibial
# accuracy:0.6017699115044248
# precision:0.6363636363636364
# recall:0.3888888888888889
# f1-score:0.4827586206896552
# AUC :  0.6114809303782599
#
#
# Pancreas
# accuracy:0.5869565217391305
# precision:0.0
# recall:0.0
# f1-score:0.0
# AUC :  0.6070415879017014
#
#
# Spleen
# accuracy:0.5208333333333334
# precision:0.7272727272727273
# recall:0.2857142857142857
# f1-score:0.4102564102564102
# AUC :  0.462890625
#
#
# Stomach
# accuracy:0.5882352941176471
# precision:0.6
# recall:0.7894736842105263
# f1-score:0.6818181818181819
# AUC :  0.6262975778546713
#
#
# Testis
# accuracy:0.4342105263157895
# precision:0.42857142857142855
# recall:0.225
# f1-score:0.2950819672131147
# AUC :  0.46208448753462605
#
#
# Thyroid
# accuracy:0.47863247863247865
# precision:0.47863247863247865
# recall:1.0
# f1-score:0.6473988439306358
# AUC :  0.4822850463876105
# c:\Users\Administrator\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\Administrator\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\metrics\_classification.py:1327: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
# large model (Emo prediction)
tissue_list = ['Adipose_Subcutaneous','Artery_Tibial','Brain_Cerebellum','Brain_Cortex',
    'Breast_Mammary_Tissue', 'Colon_Sigmoid','Colon_Transverse','Nerve_Tibial', 'Pancreas', 'Spleen','Stomach','Testis','Thyroid']
model_size = 'large'
for tissue in tissue_list:

    print('\n')
    print(tissue)
    y_true = np.load('../model/pred_results_tissue/' + model_size + '_' + tissue + '_' + 'label.npy')
    y_pred = np.load('../model/pred_results_tissue/' + model_size + '_' + tissue + '_' + 'predict.npy')

    y_score = y_pred.argmax(axis=1)       
    test_label = y_true.argmax(axis=1)                         
    y_score_pro = y_pred # (212, 2)
    y_one_hot = y_true
    y_score_one_hot = to_categorical(y_score)

    print('accuracy:{}'.format(accuracy_score(test_label, y_score)))
    print('precision:{}'.format(precision_score(test_label, y_score)))
    print('recall:{}'.format(recall_score(test_label, y_score)))
    print('f1-score:{}'.format(f1_score(test_label, y_score)))
# Out:
# Adipose_Subcutaneous
# accuracy:0.6534653465346535
# precision:0.5882352941176471
# recall:0.851063829787234
# f1-score:0.6956521739130435
#
#
# Artery_Tibial
# accuracy:0.7010309278350515
# precision:0.6875
# recall:0.8301886792452831
# f1-score:0.7521367521367521
#
#
# Brain_Cerebellum
# accuracy:0.6666666666666666
# precision:0.6842105263157895
# recall:0.8125
# f1-score:0.742857142857143
#
#
# Brain_Cortex
# accuracy:0.59375
# precision:0.6363636363636364
# recall:0.7368421052631579
# f1-score:0.6829268292682926
#
#
# Breast_Mammary_Tissue
# accuracy:0.6851851851851852
# precision:0.5862068965517241
# recall:0.7727272727272727
# f1-score:0.6666666666666667
#
#
# Colon_Sigmoid
# accuracy:0.7272727272727273
# precision:0.7391304347826086
# recall:0.7391304347826086
# f1-score:0.7391304347826085
#
#
# Colon_Transverse
# accuracy:0.8181818181818182
# precision:0.7741935483870968
# recall:0.96
# f1-score:0.8571428571428571
#
#
# Nerve_Tibial
# accuracy:0.6902654867256637
# precision:0.6301369863013698
# recall:0.8518518518518519
# f1-score:0.7244094488188976
#
#
# Pancreas
# accuracy:0.5
# precision:0.42857142857142855
# recall:0.631578947368421
# f1-score:0.5106382978723404
#
#
# Spleen
# accuracy:0.7916666666666666
# precision:0.8
# recall:0.8571428571428571
# f1-score:0.8275862068965518
#
#
# Stomach
# accuracy:0.6764705882352942
# precision:0.6818181818181818
# recall:0.7894736842105263
# f1-score:0.7317073170731707
#
#
# Testis
# accuracy:0.5789473684210527
# precision:0.5869565217391305
# recall:0.675
# f1-score:0.627906976744186
#
#
# Thyroid
# accuracy:0.6581196581196581
# precision:0.6212121212121212
# recall:0.7321428571428571
# f1-score:0.6721311475409836

# %%
import seaborn as sns
fine = [0.805,0.788,0.741,0.684,0.736,0.846,0.865,0.789,0.678,0.855,0.798,0.677,0.721]
end = [0.584,0.558,0.593,0.415,0.638,0.590,0.595,0.661,0.607,0.463,0.626,0.462,0.482]
pred = [0.738,0.786,0.712,0.641,0.726,0.801,0.840,0.749,0.635,0.847,0.753,0.659,0.714]

my_pal = {"Fine-tune": "#FFB6C1", "Emo prediction": "#4169E1", "End-to-end": "#E6E6FA"}

f, ax = plt.subplots(figsize=(4, 6))
df = pd.Series(fine, name="Fine-tune").to_frame().join(pd.Series(pred, name="Emo prediction")).join(pd.Series(end, name="End-to-end"))
sns.violinplot(data=df, palette=my_pal, bw=.3, cut=1, linewidth=1.5) 
plt.title('Tissue-specific prediction (Large Model)')
plt.ylabel('AUC')
plt.grid(axis='y')
ax.set_ylim(0.38,1.03)
plt.savefig('images/finetune/large-model.png',dpi=300,bbox_inches='tight')
plt.show()
