# %% [markdown]
# #### representation visualization of EMO model

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn import datasets
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings('ignore')

def plot_embedding(data, label, title):
    x_min, x_max = np.min(data, 0), np.max(data, 0)
    data = (data - x_min) / (x_max - x_min)

    fig = plt.figure()
    ax = plt.subplot(111)
    for i in range(data.shape[0]):
        plt.text(data[i, 0], data[i, 1], str(label[i]),
                 color=plt.cm.Set1(label[i] / 10.),
                 fontdict={'weight': 'bold', 'size': 9})
    plt.xticks([])
    plt.yticks([])
    plt.title(title)
    return fig

# %%
# load datasets
input = np.load("../../model/middle_output/small/input.npy",allow_pickle=True) 
input2 = np.load("../../model/middle_output/small/input2.npy",allow_pickle=True) 
output = np.load("../../model/middle_output/small/output.npy",allow_pickle=True) 
label = np.load("../../model/middle_output/small/label.npy",allow_pickle=True) 
label = np.argmax(label, axis=-1) # (4302,)
print(label.shape)
# Out:
# (4704,)

# %%
stack = input

fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(stack.shape)
result = tsne.fit_transform(stack)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)

color = ["#9392BE","#D5E49B"]
#color = ["#B0E0E6","#EE6363"]

ax = plt.subplots(figsize=(3,3))
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Between Branch (Small Model)')
plt.legend((s1,s2),('Down-regulation','Up-regulation') ,loc = 'best')
plt.savefig('images/tsne/input-small.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# (4704, 5)
# (4704, 2)

# %%
stack = input2

fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(stack.shape)
result = tsne.fit_transform(stack)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)

color = ["#9392BE","#D5E49B"]
#color = ["#B0E0E6","#EE6363"]

ax = plt.subplots(figsize=(3,3))
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Mutation Branch (Small Model)')
#plt.legend((s1,s2),('Down-regulation','Up-regulation') ,loc = 'best')
plt.savefig('images/tsne/input-small2.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# (4704, 9)
# (4704, 2)

# %%
fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(output.shape)
result = tsne.fit_transform(output)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)

color = ["#9392BE","#D5E49B"]
#color = ["#B0E0E6","#EE6363"]

ax = plt.subplots(figsize=(3,3))
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('the final FC layer (Small Model)')
#plt.legend((s1,s2),('Down-regulation','Up-regulation') ,loc = 'best')
plt.savefig('../images/tsne/output-small.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# (4704, 32)
# (4704, 2)

# %%
# load datasets
input = np.load("../../model/middle_output/middle/input.npy",allow_pickle=True) # (5787, 10000, 5)
input2 = np.load("../../model/middle_output/middle/input2.npy",allow_pickle=True) # (5787, 10000, 5)
output = np.load("../../model/middle_output/middle/output.npy",allow_pickle=True) # (5787, 32)
label = np.load("../../model/middle_output/middle/label.npy",allow_pickle=True) # (5787, 2)
label = np.argmax(label, axis=-1) # (5787,)
print(label.shape)
# Out:
# (5752,)

# %%
stack = input

fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(stack.shape)
result = tsne.fit_transform(stack)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)

color = ["#9392BE","#D5E49B"]
#color = ["#B0E0E6","#EE6363"]

ax = plt.subplots(figsize=(3,3))
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Between Branch (Medium Model)')
#plt.legend((s1,s2),('Down-regulation','Up-regulation') ,loc = 'best')
plt.savefig('../images/tsne/input-middle.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# (5752, 5)
# (5752, 2)

# %%
stack = input2

fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(stack.shape)
result = tsne.fit_transform(stack)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)

color = ["#9392BE","#D5E49B"]
#color = ["#B0E0E6","#EE6363"]

ax = plt.subplots(figsize=(3,3))
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Mutation Branch (Medium Model)')
#plt.legend((s1,s2),('Down-regulation','Up-regulation') ,loc = 'best')
plt.savefig('../images/tsne/input-middle2.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# (5752, 9)
# (5752, 2)

# %%
fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(output.shape)
result = tsne.fit_transform(output)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)

color = ["#9392BE","#D5E49B"]
#color = ["#B0E0E6","#EE6363"]

ax = plt.subplots(figsize=(3,3))
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('the final FC layer (Medium Model)')
#plt.legend((s1,s2),('Down-regulation','Up-regulation') ,loc = 'best')
plt.savefig('../images/tsne/output-middle.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# (5752, 32)
# (5752, 2)

# %%
# load datasets
input = np.load("../../model/middle_output/large/input.npy",allow_pickle=True) # have been sumed by axis-1 before
input2 = np.load("../../model/middle_output/large/input2.npy",allow_pickle=True) 
output = np.load("../../model/middle_output/large/output.npy",allow_pickle=True) 
label = np.load("../../model/middle_output/large/label.npy",allow_pickle=True) 
label = np.argmax(label, axis=-1)

# %%
stack = input

fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
result = tsne.fit_transform(stack)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)

color = ["#9392BE","#D5E49B"]
#color = ["#B0E0E6","#EE6363"]

ax = plt.subplots(figsize=(3,3))
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Between Branch (Large Model)')
#plt.legend((s1,s2),('Down-regulation','Up-regulation') ,loc = 'best')
plt.savefig('../images/tsne/input-large.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
stack = input2

fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(stack.shape)
result = tsne.fit_transform(stack)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)

color = ["#9392BE","#D5E49B"]
#color = ["#B0E0E6","#EE6363"]

ax = plt.subplots(figsize=(3,3))
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Mutation Branch (Large Model)')
#plt.legend((s1,s2),('Down-regulation','Up-regulation') ,loc = 'best')
plt.savefig('../images/tsne/input-large2.png',dpi=300, bbox_inches = 'tight')
plt.show()
# Out:
# (9029, 9)
# (9029, 2)

# %%
fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0, n_iter=5000)
result = tsne.fit_transform(output)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)

color = ["#9392BE","#D5E49B"]
#color = ["#B0E0E6","#EE6363"]

ax = plt.subplots(figsize=(3,3))
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])

plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('the final FC layer (Large Model)')
#plt.legend((s1,s2),('Down-regulation','Up-regulation') ,loc = 'best')
plt.savefig('../images/tsne/output-large.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
# load datasets (merge after batch processing)
input1 = np.load("../../model/middle_output/huge/input1.npy",allow_pickle=True) # (1000, 5) have been sumed by axis-1 before
output1 = np.load("../../model/middle_output/huge/output1.npy",allow_pickle=True) # (1000, 32)
label1 = np.load("../../model/middle_output/huge/label1.npy",allow_pickle=True) 
input22 = np.load("../../model/middle_output/huge/input22.npy",allow_pickle=True) 
output22 = np.load("../../model/middle_output/huge/output22.npy",allow_pickle=True) 
label22 = np.load("../../model/middle_output/huge/label22.npy",allow_pickle=True) 
input23 = np.load("../../model/middle_output/huge/input23.npy",allow_pickle=True) 
output23 = np.load("../../model/middle_output/huge/output23.npy",allow_pickle=True) 
label23 = np.load("../../model/middle_output/huge/label23.npy",allow_pickle=True) 
input24 = np.load("../../model/middle_output/huge/input24.npy",allow_pickle=True) 
output24 = np.load("../../model/middle_output/huge/output24.npy",allow_pickle=True) 
label24 = np.load("../../model/middle_output/huge/label24.npy",allow_pickle=True) 
input25 = np.load("../../model/middle_output/huge/input25.npy",allow_pickle=True) 
output25 = np.load("../../model/middle_output/huge/output25.npy",allow_pickle=True) 
label25 = np.load("../../model/middle_output/huge/label25.npy",allow_pickle=True) 
input3 = np.load("../../model/middle_output/huge/input3.npy",allow_pickle=True) # (800, 5) have been sumed by axis-1 before
output3 = np.load("../../model/middle_output/huge/output3.npy",allow_pickle=True) # (800, 32)
label3 = np.load("../../model/middle_output/huge/label3.npy",allow_pickle=True) 
input = np.concatenate([input1, input22, input23, input24, input25, input3], axis=0)
output = np.concatenate([output1, output22, output23, output24, output25, output3], axis=0)
label = np.concatenate([label1, label22, label23, label24, label25, label3], axis=0)
label = np.argmax(label, axis=-1)

# %%
stack = input

fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
result = tsne.fit_transform(stack)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)

color = ["#9392BE","#D5E49B"]
#color = ["#B0E0E6","#EE6363"]

ax = plt.subplots(figsize=(3,3))
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Between Branch (Huge Model)')
#plt.legend((s1,s2),('Down-regulation','Up-regulation') ,loc = 'best')
plt.savefig('../images/tsne/input-huge.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
input2 = np.load("../../model/middle_output/huge/input2.npy",allow_pickle=True) 
stack = input2[0:2600]
fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
#print(stack.shape)
result = tsne.fit_transform(stack)
#print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)

color = ["#9392BE","#D5E49B"]
#color = ["#B0E0E6","#EE6363"]

ax = plt.subplots(figsize=(3,3))
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Mutation Branch (Huge Model)')
#plt.legend((s1,s2),('Down-regulation','Up-regulation') ,loc = 'best')
plt.savefig('../images/tsne/input-huge2.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0, n_iter=5000)
result = tsne.fit_transform(output)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)

color = ["#9392BE","#D5E49B"]
#color = ["#B0E0E6","#EE6363"]

ax = plt.subplots(figsize=(3,3))
for i in range(result.shape[0]):
    if(label[i] == 0):
        s1 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])
for i in range(result.shape[0]):
    if(label[i] == 1):
        s2 = plt.scatter(result[i, 0], result[i, 1],s=2,color=color[label[i]])

plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('the final FC layer (Huge Model)')
#plt.legend((s1,s2),('Down-regulation','Up-regulation') ,loc = 'best')
plt.savefig('../images/tsne/output-huge.png',dpi=300, bbox_inches = 'tight')
plt.show()
