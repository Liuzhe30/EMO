# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn import datasets
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings('ignore')

def plot_embedding(data, label, title):
    x_min, x_max = np.min(data, 0), np.max(data, 0)
    data = (data - x_min) / (x_max - x_min)

    fig = plt.figure()
    ax = plt.subplot(111)
    for i in range(data.shape[0]):
        plt.text(data[i, 0], data[i, 1], str(label[i]),
                 color=plt.cm.Set1(label[i] / 10.),
                 fontdict={'weight': 'bold', 'size': 9})
    plt.xticks([])
    plt.yticks([])
    plt.title(title)
    return fig

# %%
# load datasets
input = np.load("../../model/middle_output_slope/small/input.npy",allow_pickle=True) 
input2 = np.load("../../model/middle_output_slope/small/input2.npy",allow_pickle=True) 
output = np.load("../../model/middle_output_slope/small/output.npy",allow_pickle=True) 
label = np.load("../../model/middle_output_slope/small/label.npy",allow_pickle=True) 
print(label.shape)
# Out:
# (4704,)

# %%
stack = input

fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(stack.shape)
result = tsne.fit_transform(stack)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)
# Out:
# (4704, 5)
# (4704, 2)

# %%
num = result.shape[0]
ax = plt.subplots(figsize=(3,4))
sizes = label

plt.scatter(result[:,0], result[:,1], c=sizes, s=5, cmap='twilight_shifted', alpha=0.5)
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Between Branch\n(Slope Regression, Small Model)')
plt.colorbar(label='slope value', orientation='horizontal') 
plt.savefig('../images/tsne/slope-input-small.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
stack = input2

fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(stack.shape)
result = tsne.fit_transform(stack)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)
# Out:
# (4704, 9)
# (4704, 2)

# %%
num = result.shape[0]
ax = plt.subplots(figsize=(3,4))
sizes = label

plt.scatter(result[:,0], result[:,1], c=sizes, s=5, cmap='twilight_shifted', alpha=0.5)
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Mutation Branch\n(Slope Regression, Small Model)')
plt.colorbar(label='slope value', orientation='horizontal') 
plt.savefig('../images/tsne/slope-input-small2.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(output.shape)
result = tsne.fit_transform(output)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)
# Out:
# (4704, 32)
# (4704, 2)

# %%
num = result.shape[0]
ax = plt.subplots(figsize=(3,4))
sizes = label

plt.scatter(result[:,0], result[:,1], c=sizes, s=5, cmap='twilight_shifted', alpha=0.5)
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('the final FC layer\n(Slope Regression, Small Model)')
plt.colorbar(label='slope value', orientation='horizontal') 
plt.savefig('../images/tsne/slope-output-small.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
# load datasets
input = np.load("../../model/middle_output_slope/middle/input.npy",allow_pickle=True) 
input2 = np.load("../../model/middle_output_slope/middle/input2.npy",allow_pickle=True) 
output = np.load("../../model/middle_output_slope/middle/output.npy",allow_pickle=True) 
label = np.load("../../model/middle_output_slope/middle/label.npy",allow_pickle=True) 
print(label.shape)
# Out:
# (5752,)

# %%
stack = input

fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(stack.shape)
result = tsne.fit_transform(stack)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)
# Out:
# (5752, 5)
# (5752, 2)

# %%
num = result.shape[0]
ax = plt.subplots(figsize=(3,4))
sizes = label

plt.scatter(result[:,0], result[:,1], c=sizes, s=5, cmap='twilight_shifted', alpha=0.5)
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Between Branch\n(Slope Regression, Medium Model)')
plt.colorbar(label='slope value', orientation='horizontal') 
plt.savefig('../images/tsne/slope-input-middle.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
stack = input2

fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(stack.shape)
result = tsne.fit_transform(stack)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)
# Out:
# (5752, 9)
# (5752, 2)

# %%
num = result.shape[0]
ax = plt.subplots(figsize=(3,4))
sizes = label

plt.scatter(result[:,0], result[:,1], c=sizes, s=5, cmap='twilight_shifted', alpha=0.5)
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Mutation Branch\n(Slope Regression, Medium Model)')
plt.colorbar(label='slope value', orientation='horizontal') 
plt.savefig('../images/tsne/slope-input-middle2.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(output.shape)
result = tsne.fit_transform(output)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)
# Out:
# (5752, 32)
# (5752, 2)

# %%
num = result.shape[0]
ax = plt.subplots(figsize=(3,4))
sizes = label

plt.scatter(result[:,0], result[:,1], c=sizes, s=5, cmap='twilight_shifted', alpha=0.5)
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('the final FC layer\n(Slope Regression, Medium Model)')
plt.colorbar(label='slope value', orientation='horizontal') 
plt.savefig('../images/tsne/slope-output-middle.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
# load datasets
input = np.load("../../model/middle_output_slope/large/input.npy",allow_pickle=True) 
input2 = np.load("../../model/middle_output_slope/large/input2.npy",allow_pickle=True) 
output = np.load("../../model/middle_output_slope/large/output.npy",allow_pickle=True) 
label = np.load("../../model/middle_output_slope/large/label.npy",allow_pickle=True) 
print(label.shape)
# Out:
# (9029,)

# %%
stack = input

fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(stack.shape)
result = tsne.fit_transform(stack)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)
# Out:
# (9029, 5)
# (9029, 2)

# %%
num = result.shape[0]
ax = plt.subplots(figsize=(3,4))
sizes = label

plt.scatter(result[:,0], result[:,1], c=sizes, s=5, cmap='twilight_shifted', alpha=0.5)
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Between Branch\n(Slope Regression, Large Model)')
plt.colorbar(label='slope value', orientation='horizontal') 
plt.savefig('../images/tsne/slope-input-large.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
stack = input2

fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(stack.shape)
result = tsne.fit_transform(stack)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)
# Out:
# (9029, 9)
# (9029, 2)

# %%
num = result.shape[0]
ax = plt.subplots(figsize=(3,4))
sizes = label

plt.scatter(result[:,0], result[:,1], c=sizes, s=5, cmap='twilight_shifted', alpha=0.5)
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Mutation Branch\n(Slope Regression, Large Model)')
plt.colorbar(label='slope value', orientation='horizontal') 
plt.savefig('../images/tsne/slope-input-large2.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(output.shape)
result = tsne.fit_transform(output)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)
# Out:
# (9029, 32)
# (9029, 2)

# %%
num = result.shape[0]
ax = plt.subplots(figsize=(3,4))
sizes = label

plt.scatter(result[:,0], result[:,1], c=sizes, s=5, cmap='twilight_shifted', alpha=0.5)
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('the final FC layer\n(Slope Regression, Large Model)')
plt.colorbar(label='slope value', orientation='horizontal') 
plt.savefig('../images/tsne/slope-output-large.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
import numpy as np

data_types = ["input", "input2", "output", "label"]
num_files = 16  
base_path = "../../model/middle_output_slope/huge/"

data = {dtype: [] for dtype in data_types}

for i in range(1, num_files + 1):
    for dtype in data_types:
        file_path = f"{base_path}{dtype}_{i}.npy"
        data[dtype].append(np.load(file_path, allow_pickle=True))

input = np.concatenate(data["input"], axis=0)
input2 = np.concatenate(data["input2"], axis=0)
output = np.concatenate(data["output"], axis=0)
label = np.concatenate(data["label"], axis=0)

print(label.shape)
# Out:
# (1900,)

# %%
stack = input

fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(stack.shape)
result = tsne.fit_transform(stack)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)
# Out:
# (1900, 5)
# (1900, 2)

# %%
num = result.shape[0]
ax = plt.subplots(figsize=(3,4))
sizes = label

plt.scatter(result[:,0], result[:,1], c=sizes, s=5, cmap='twilight_shifted', alpha=0.5)
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Between Branch\n(Slope Regression, Huge Model)')
plt.colorbar(label='slope value', orientation='horizontal') 
plt.savefig('../images/tsne/slope-input-huge.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
stack = input2

fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(stack.shape)
result = tsne.fit_transform(stack)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)
# Out:
# (1900, 9)
# (1900, 2)

# %%
num = result.shape[0]
ax = plt.subplots(figsize=(3,4))
sizes = label

plt.scatter(result[:,0], result[:,1], c=sizes, s=5, cmap='twilight_shifted', alpha=0.5)
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('Mutation Branch\n(Slope Regression, Huge Model)')
plt.colorbar(label='slope value', orientation='horizontal') 
plt.savefig('../images/tsne/slope-input-huge2.png',dpi=300, bbox_inches = 'tight')
plt.show()

# %%
fig = plt.figure()
tsne = TSNE(n_components=2, init='pca', random_state=0)
print(output.shape)
result = tsne.fit_transform(output)
print(result.shape)
#fig = plot_embedding(result, label,'t-SNE embedding of the digits')
x_min, x_max = np.min(result, 0), np.max(result, 0)
result = (result - x_min) / (x_max - x_min)
# Out:
# (1900, 32)
# (1900, 2)

# %%
num = result.shape[0]
ax = plt.subplots(figsize=(3,4))
sizes = label

plt.scatter(result[:,0], result[:,1], c=sizes, s=5, cmap='twilight_shifted', alpha=0.5)
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.title('the final FC layer\n(Slope Regression, Huge Model)')
plt.colorbar(label='slope value', orientation='horizontal') 
plt.savefig('../images/tsne/slope-output-huge.png',dpi=300, bbox_inches = 'tight')
plt.show()
