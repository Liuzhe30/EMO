# %% [markdown]
# #### prediction performance of Enformer

# %%
import numpy as np
from sklearn.metrics import mean_squared_error
from scipy.stats import pearsonr
from prettytable import PrettyTable

# %%
result_path = '../../../datasets/tissue_specific/enformer_prediction_results_slope/'

compare_tissue_list = ['Adipose_Subcutaneous','Artery_Tibial','Breast_Mammary_Tissue','Colon_Transverse','Nerve_Tibial','Thyroid']
model_size_list = ['small','middle','large']

# %%
for tissue in compare_tissue_list:
    for model_size in model_size_list:
        label = np.load(result_path + model_size + '_' + tissue + '_label.npy')
        y_pred = np.load(result_path + model_size + '_' + tissue + '_prediction.npy')

        # Ensure both arrays are of same length
        min_len = min(len(label), len(y_pred))
        label = label[:min_len]
        y_pred = y_pred[:min_len]

        # Calculate metrics
        mse = np.round(mean_squared_error(label, y_pred), 4)
        pcc, _ = pearsonr(label, y_pred)
        pcc = np.round(pcc, 4)

        # Print results
        print(f'Tissue: {tissue}')
        print(f'Model size: {model_size}')
        table = PrettyTable(['PCC', 'MSE'])
        table.add_row([pcc, mse])
        print(table)
# Out:
# Tissue: Adipose_Subcutaneous
# Model size: small
# +--------+------------------------+
# |  PCC   |          MSE           |
# +--------+------------------------+
# | 0.0406 | 1.1614140782642675e+34 |
# +--------+------------------------+
# Tissue: Adipose_Subcutaneous
# Model size: middle
# +---------+------------------------+
# |   PCC   |          MSE           |
# +---------+------------------------+
# | -0.0131 | 1.2347051407449903e+34 |
# +---------+------------------------+
# Tissue: Adipose_Subcutaneous
# Model size: large
# +---------+-----------------------+
# |   PCC   |          MSE          |
# +---------+-----------------------+
# | -0.0335 | 1.992434969143309e+33 |
# +---------+-----------------------+
# Tissue: Artery_Tibial
# Model size: small
# +--------+-----------------------+
# |  PCC   |          MSE          |
# +--------+-----------------------+
# | 0.1008 | 4.205770170230694e+33 |
# +--------+-----------------------+
# Tissue: Artery_Tibial
# Model size: middle
# +--------+-----------------------+
# |  PCC   |          MSE          |
# +--------+-----------------------+
# | 0.0798 | 6.685682756197031e+33 |
# +--------+-----------------------+
# Tissue: Artery_Tibial
# Model size: large
# +---------+-----------------------+
# |   PCC   |          MSE          |
# +---------+-----------------------+
# | -0.0161 | 3.090322845247493e+33 |
# +---------+-----------------------+
# Tissue: Breast_Mammary_Tissue
# Model size: small
# +--------+-----------------------+
# |  PCC   |          MSE          |
# +--------+-----------------------+
# | 0.5119 | 7.476521990417533e+33 |
# +--------+-----------------------+
# Tissue: Breast_Mammary_Tissue
# Model size: middle
# +---------+------------------------+
# |   PCC   |          MSE           |
# +---------+------------------------+
# | -0.3571 | 4.6272005189827657e+33 |
# +---------+------------------------+
# Tissue: Breast_Mammary_Tissue
# Model size: large
# +---------+------------------------+
# |   PCC   |          MSE           |
# +---------+------------------------+
# | -0.1273 | 2.9069471436066514e+33 |
# +---------+------------------------+
# Tissue: Colon_Transverse
# Model size: small
# +--------+------------------------+
# |  PCC   |          MSE           |
# +--------+------------------------+
# | 0.1616 | 1.8433585038393561e+34 |
# +--------+------------------------+
# Tissue: Colon_Transverse
# Model size: middle
# +--------+-----------------------+
# |  PCC   |          MSE          |
# +--------+-----------------------+
# | -0.211 | 5.413516478624236e+33 |
# +--------+-----------------------+
# Tissue: Colon_Transverse
# Model size: large
# +--------+-----------------------+
# |  PCC   |          MSE          |
# +--------+-----------------------+
# | 0.0615 | 4.073499391047261e+33 |
# +--------+-----------------------+
# Tissue: Nerve_Tibial
# Model size: small
# +---------+------------------------+
# |   PCC   |          MSE           |
# +---------+------------------------+
# | -0.3062 | 3.0568506072035387e+33 |
# +---------+------------------------+
# Tissue: Nerve_Tibial
# Model size: middle
# +---------+-----------------------+
# |   PCC   |          MSE          |
# +---------+-----------------------+
# | -0.0928 | 7.109862705282277e+33 |
# +---------+-----------------------+
# Tissue: Nerve_Tibial
# Model size: large
# +--------+-----------------------+
# |  PCC   |          MSE          |
# +--------+-----------------------+
# | 0.0401 | 2.290112752390183e+33 |
# +--------+-----------------------+
# Tissue: Thyroid
# Model size: small
# +---------+-----------------------+
# |   PCC   |          MSE          |
# +---------+-----------------------+
# | -0.0912 | 5.897850793263165e+33 |
# +---------+-----------------------+
# Tissue: Thyroid
# Model size: middle
# +---------+------------------------+
# |   PCC   |          MSE           |
# +---------+------------------------+
# | -0.2717 | 1.8895827732188134e+34 |
# +---------+------------------------+
# Tissue: Thyroid
# Model size: large
# +--------+------------------------+
# |  PCC   |          MSE           |
# +--------+------------------------+
# | 0.0352 | 2.7432115727634714e+33 |
# +--------+------------------------+
